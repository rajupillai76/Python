# %%
import psycopg2 as pg

# %%
conn = pg.connect("host=localhost dbname=hermesdb")
cur = conn.cursor()
cur.execute('select * from hermes.students')
onerow = cur.fetchone()

# %%
onerow
# Out:
# ('S1028',
#  'Andrew',
#  'Keith',
#  'Barnes',
#  'English',
#  'White',
#  'FALSE',
#  None,
#  '11',
#  None,
#  'FALSE',
#  Decimal('1943114544'),
#  datetime.date(1999, 6, 1),
#  'M',
#  'NA ',
#  'Inactive',
#  'Determined Ineligible',
#  None,
#  None,
#  None,
#  None,
#  'FALSE')

# %%
fetch5 = cur.fetchmany(5)
fetch5
# Out:
# [('S1082',
#   'Xavier',
#   'Lee',
#   'Heard',
#   'English',
#   'White',
#   'FALSE',
#   None,
#   '12',
#   datetime.date(2018, 5, 25),
#   'TRUE',
#   Decimal('1942048925'),
#   datetime.date(1999, 7, 8),
#   'M',
#   'NA ',
#   'Inactive',
#   'Specific Learning Disability',
#   None,
#   None,
#   None,
#   None,
#   'FALSE'),
#  ('S1098',
#   'Cameron',
#   'Ann',
#   'Miller',
#   'English',
#   'White',
#   'FALSE',
#   None,
#   '12',
#   datetime.date(2018, 5, 25),
#   'TRUE',
#   Decimal('1943836583'),
#   datetime.date(2000, 8, 16),
#   'F',
#   'NA ',
#   'Inactive',
#   'Determined Ineligible',
#   None,
#   None,
#   None,
#   None,
#   'FALSE'),
#  ('S1132',
#   'Brittany',
#   'Kianna',
#   'Welch',
#   'English',
#   'Black/African American',
#   'FALSE',
#   None,
#   '10',
#   None,
#   'FALSE',
#   Decimal('1942073592'),
#   datetime.date(1998, 12, 2),
#   'F',
#   'NA ',
#   'Inactive',
#   'Specific Learning Disability',
#   None,
#   None,
#   None,
# ...

# %%
allrows = cur.fetchall()
allrows
# Out:
# [('S1082',
#   'Xavier',
#   'Lee',
#   'Heard',
#   'English',
#   'White',
#   'FALSE',
#   None,
#   '12',
#   datetime.date(2018, 5, 25),
#   'TRUE',
#   Decimal('1942048925'),
#   datetime.date(1999, 7, 8),
#   'M',
#   'NA ',
#   'Inactive',
#   'Specific Learning Disability',
#   None,
#   None,
#   None,
#   None,
#   'FALSE'),
#  ('S1098',
#   'Cameron',
#   'Ann',
#   'Miller',
#   'English',
#   'White',
#   'FALSE',
#   None,
#   '12',
#   datetime.date(2018, 5, 25),
#   'TRUE',
#   Decimal('1943836583'),
#   datetime.date(2000, 8, 16),
#   'F',
#   'NA ',
#   'Inactive',
#   'Determined Ineligible',
#   None,
#   None,
#   None,
#   None,
#   'FALSE'),
#  ('S1132',
#   'Brittany',
#   'Kianna',
#   'Welch',
#   'English',
#   'Black/African American',
#   'FALSE',
#   None,
#   '10',
#   None,
#   'FALSE',
#   Decimal('1942073592'),
#   datetime.date(1998, 12, 2),
#   'F',
#   'NA ',
#   'Inactive',
#   'Specific Learning Disability',
#   None,
#   None,
#   None,
# ...
