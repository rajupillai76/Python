# %%
import pandas as pd
from pandas import DataFrame as df
import pyarrow as pa
import pyarrow.parquet as pq
from datetime import datetime

# %%
#dataset1 = pq.ParquetDataset('/Users/raju.pillai/gitrepo/python/data/DataAcquisition/output/pqt/osfdata_part_parquet711')

# %%
dataset1 = DataFrame(pd.read_parquet('/Users/raju.pillai/gitrepo/python/data/DataAcquisition/output/pqt/osfdata_part_parquet711'))

# %%
dataset2 = DataFrame(pd.read_parquet('/Users/raju.pillai/gitrepo/python/data/DataAcquisition/output/pqt/osfdata_part_parquet95'))

# %%
dataset1.append(dataset2,ignore_index = True, sort = True)
# Out:
#         ARC_IATA_Number Action_Code Adjustment_Amount Affiliation_Of_TA  \
# 0            R106139207          HI               nan
# 1            R106139207          HI               nan
# 2            R105445688          EX               nan
# 3            R105445688          EX               nan
# 4            R105227086          EX               nan
# ...                 ...         ...               ...               ...
# 2336203             nan         nan               nan               nan
# 2336204             nan         nan               nan               nan
# 2336205             nan         nan               nan               nan
# 2336206             nan         nan               nan               nan
# 2336207             nan         nan               nan               nan
#
#         Agency_Address_1 Agency_Address_2 Agency_Address_3 Agency_City  \
# 0                   None             None                         None
# ...

# %%
dataset1.columns
# Out:
# Index(['File_Source', 'File_Timestamp', 'Record_Type', 'Payment_Record_Type',
#        'Action_Code', 'Payment_Record_Number', 'Chain_Property_ID',
#        'Booking_Source', 'Chain_Confirmation_Number',
#        'Secondary_Confirmation_Number', 'Chain_Cancellation_Number',
#        'Cancellation_Origination_Code', 'Corporate_ID_Number',
#        'ARC_IATA_Number', 'Group_Guest_Last_Name', 'Group_Guest_First_Name',
#        'PNR_Number', 'GNR_Number', 'GNR_Sequence_Number', 'Record_Status_Code',
#        'Record_Reason_Code', 'Arrival_Date', 'Departure_Date', 'Booking_Date',
#        'Room_Type', 'Number_of_Nights', 'Number_of_Rooms',
#        'Commissionable_Revenue', 'Gross_Commission_Due', 'Adjustment_Amount',
#        'Net_Commission_Due', 'Commission_Percentage', 'Commission_Flat_Amount',
#        'Transaction_Currency_Code', 'Total_Tax_Records', 'Total_Tax_Amount',
#        'Rate_Plan', 'Promotion_Code', 'Agency_Name', 'Agency_Address_1',
# ...

# %%
#dataset2 = pq.ParquetDataset('/Users/raju.pillai/gitrepo/python/data/DataAcquisition/output/pqt/osfdata_part_parquet95')

# %%
#df["Brand_Code"].value_counts()

# %%
table = pa.Table.from_pandas(dataset1)

# %%
pq.write_to_dataset(table, root_path = '/Users/raju.pillai/gitrepo/python/data/DataAcquisition/output/stay/osfdata_part95_711_parquet',partition_cols=['Brand_Code'], compression='none', use_dictionary=False)
