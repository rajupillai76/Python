# %%
import pandas as pd

# %%
df = pd.read_csv('data/MonthlyProductSales.csv',encoding = "ISO-8859-1")

# %%
df
# Out:
#      Month of Order Date                                       Product Name  \
# 0                 5/1/13   1.7 Cubic Foot Compact Cube Office Refrigerators
# 1                 6/1/15   1.7 Cubic Foot Compact Cube Office Refrigerators
# 2                11/1/13   1.7 Cubic Foot Compact Cube Office Refrigerators
# 3                 7/1/16   1.7 Cubic Foot Compact Cube Office Refrigerators
# 4                11/1/16   1.7 Cubic Foot Compact Cube Office Refrigerators
# 5                 8/1/15   1.7 Cubic Foot Compact Cube Office Refrigerators
# 6                11/1/13  1/4 Fold Party Design Invitations & White Enve...
# 7                11/1/14  1/4 Fold Party Design Invitations & White Enve...
# 8                12/1/14                                 3-ring staple pack
# 9                 1/1/13                                 3-ring staple pack
# 10                8/1/14                                 3-ring staple pack
# ...

# %%
df.describe()
# Out:
#               Sales
# count   9252.000000
# mean     248.308798
# std      669.441779
# min        0.000000
# 25%       18.000000
# 50%       60.000000
# 75%      222.000000
# max    22638.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9252 entries, 0 to 9251
# Data columns (total 3 columns):
# Month of Order Date    9252 non-null object
# Product Name           9252 non-null object
# Sales                  9252 non-null int64
# dtypes: int64(1), object(2)
# memory usage: 216.9+ KB

# %%
s = df['Product Name']

# %%
s.value_counts(dropna=False)
# Out:
# Easy-staple paper                                                                      32
# Staples                                                                                30
# Staple envelope                                                                        30
# Staples in misc. colors                                                                18
# KI Adjustable-Height Table                                                             14
# Storex Dura Pro Binders                                                                14
# Avery Non-Stick Binders                                                                14
# Situations Contoured Folding Chairs, 4/Set                                             14
# Staple remover                                                                         13
# Staple-based wall hangings                                                             13
# ...

# %%
df.groupby('Product Name').sum()
# Out:
#                                                     Sales
# Product Name
# #10 Gummed Flap White Envelopes, 100/Box               42
# #10 Self-Seal White Envelopes                         109
# #10 White Business Envelopes,4 1/8 x 9 1/2            489
# #10- 4 1/8 x 9 1/2 Recycled Envelopes                 286
# #10- 4 1/8 x 9 1/2 Security-Tint Envelopes            147
# #10-4 1/8 x 9 1/2 Premium Diagonal Seam Envelopes     176
# #6 3/4 Gummed Flap White Envelopes                     72
# 1.7 Cubic Foot Compact Cube Office Refrigerators     2706
# 1/4 Fold Party Design Invitations & White Envel...     50
# 12 Colored Short Pencils                               18
# 12-1/2 Diameter Round Wall Clock                      552
# 14-7/8 x 11 Blue Bar Computer Printout Paper          422
# 2300 Heavy-Duty Transfer File Systems by Perma        345
# 24 Capacity Maxi Data Binder Racks, Pearl            3537
# 24-Hour Round Wall Clock                              488
# ...

# %%
df.groupby('Month of Order Date').sum()
# Out:
#                       Sales
# Month of Order Date
# 1/1/13                14239
# 1/1/14                18172
# 1/1/15                18548
# 1/1/16                44709
# 10/1/13               31449
# 10/1/14               31406
# 10/1/15               56468
# 10/1/16               77785
# 11/1/13               78634
# 11/1/14               75979
# 11/1/15               82194
# 11/1/16              118457
# 12/1/13               69543
# 12/1/14               74923
# 12/1/15               97248
# 12/1/16               83831
# 2/1/13                 4518
# 2/1/14                11954
# 2/1/15                22868
# 2/1/16                20306
# 3/1/13                55689
# 3/1/14                38731
# 3/1/15                51184
# 3/1/16                58882
# 4/1/13                28296
# 4/1/14                34195
# 4/1/15                39254
# 4/1/16                36525
# 5/1/13                23649
# 5/1/14                30136
# 5/1/15                56693
# ...
